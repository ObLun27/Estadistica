# %% [markdown]
# <a href="https://colab.research.google.com/github/ObLun27/Estadistica/blob/main/Unidad4/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![nuevo_logos.png](data:image/png;base64,...)
#
#
#
#
# #Probabilidad y Estadistica
# ##Unidad 4 Distribucion de probabilidad
# Practica: 1, 2 y 3
#
# Distribucion normal, binomial y poisson
#
# Alumno: Obed Alejandro Luna Garcia
#
# Grupo: 2YY
#
# Profesor: José Gabriel Rodríguez Rivas

# %% [markdown]
# #Distribucion Normal
# ##Ejercicio 1

# %% [markdown]
# Una revision de los pesos de 500 estudiantes del ITD, evidenció que la media es de 70 kilogramos y la desviacion estandar es de 4 kilogramos. Suponiendo que los valores se distribuyen normalmente. Hallar lo siguiente:
#
# * Generar aleatoriamente las edades de los 500 estudiantes con una media de 70kg y una desviacion estandar de 4kg
# * Realizar un histograma de las edades.
# * Graficar la función de densidad de probabilidad (PDF).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generar edades aleatorias con una media de 70kg y una desviación estándar de 4kg
media = 70
desvEst = 4
nDatos = 500
edades = np.random.normal(media, desvEst, nDatos)
edades[0:50] # mostrar los primeros 50
# Out:
# array([73.61548761, 71.60726401, 65.90511203, 65.43345577, 71.93688168,
#        63.74196909, 74.87186506, 75.57431866, 62.5965004 , 76.32523495,
#        70.94676992, 71.00734355, 73.17425851, 69.1437869 , 70.82376574,
#        70.16946071, 64.2923314 , 71.83305941, 72.65241849, 73.82914295,
#        71.85145322, 65.32689933, 68.2303257 , 71.77253795, 71.04861105,
#        74.07956516, 72.87777371, 75.48983579, 75.62829636, 68.69994015,
#        66.95554406, 76.03828311, 75.65270821, 69.21834326, 65.05131786,
#        68.50676499, 68.54434479, 69.26553048, 73.45811821, 62.27768323,
#        64.12805732, 69.38261715, 68.02659344, 74.43576397, 76.05188165,
#        71.78303866, 68.21158991, 74.14696578, 74.11613785, 68.05323735])

# %%
#Crear rango de valores para crear la densidad
rango = np.linspace(media - 3 * desvEst, media + 3 * desvEst, nDatos)
#Calcular la PDF de la distribucion normal
pdf = 1 / (desvEst * np.sqrt(2 * np.pi)) * np.exp(-(rango - media) ** 2 / (2 * desvEst ** 2))
print("Imprimir los primeros 50 valores del rango")
print(rango[0:50])
print("Imprimir los primeros 50 valores de la PDF")
print(pdf[0:50])
# Out:
# Imprimir los primeros 50 valores del rango
# [58.         58.04809619 58.09619238 58.14428858 58.19238477 58.24048096
#  58.28857715 58.33667335 58.38476954 58.43286573 58.48096192 58.52905812
#  58.57715431 58.6252505  58.67334669 58.72144289 58.76953908 58.81763527
#  58.86573146 58.91382766 58.96192385 59.01002004 59.05811623 59.10621242
#  59.15430862 59.20240481 59.250501   59.29859719 59.34669339 59.39478958
#  59.44288577 59.49098196 59.53907816 59.58717435 59.63527054 59.68336673
#  59.73146293 59.77955912 59.82765531 59.8757515  59.9238477  59.97194389
#  60.02004008 60.06813627 60.11623246 60.16432866 60.21242485 60.26052104
#  60.30861723 60.35671343]
# Imprimir los primeros 50 valores de la PDF
# [0.00110796 0.00114858 0.0011905  0.00123379 0.00127846 0.00132455
#  0.00137211 0.00142118 0.00147178 0.00152397 0.00157777 0.00163325
#  0.00169042 0.00174935 0.00181007 0.00187262 0.00193706 0.00200342
#  0.00207176 0.00214212 0.00221455 0.0022891  0.00236581 0.00244475
# ...

# %%
plt.figure(figsize=(6, 4))
plt.hist(edades, bins=15, alpha=0.4, color='b')
plt.title('Distribucion Normal')
plt.xlabel("Peso en kg de los estudiantes")
plt.grid(True)
plt.show()

# %%
#Visualizar la PDF
plt.figure(figsize=(6, 4))
plt.plot(rango, pdf, label='Normal:(media:{})'.format(np.round(media,2), np.round(desvEst,2)))
plt.title('Funcion de Densidad de Probabilidad (PDF) - Distribucion Normal')
plt.xlabel("Peso en kg de los estudiantes")
plt.ylabel("Densidad de Probabilidad")
plt.legend()
plt.grid(True)
plt.show()

# %%
#Graficar Histograma
plt.figure(figsize=(6, 4))
plt.hist(edades, bins=15, density=True, alpha=0.4, color='b')
plt.plot(rango, pdf, 'k', linewidth=2)
plt.title('Distribucion Normal')
plt.xlabel("Peso en kg de los estudiantes")
plt.grid(True)
plt.show()

# %% [markdown]
# #Ejercicio 2
# Encontrar
# * cuantos estudiantes pesan menos de 75kg.
# * Cuantos estudiantes pesan menos de 62kg.
# * Cuantos estuidantes pesan mas de 79kg.
# Primero nececitamos calcular la probabilidad de que un estudiante pese menos de 75kg utilizando la funcion de distribución acumulativa (CDF) de la distribucion normal.

# %%
plt.figure (figsize=(6, 4))
media = 70
desvEst = 4
totalEstudiantes = 500
pesoLim = 79 #Variable para calcular la probabilidad de que un estudiante pese menos de 79kg

probMenos75 = norm.cdf(pesoLim, media, desvEst)
#Ahora calculamos el numero de estudiantes que pesan menos de 75kg
numMenos75 = probMenos75 * totalEstudiantes
print("Probabilidad de que un estudiante pese menos de 75kg", probMenos75)
print("Numero de estudiantes que pesan menos de 75kg:", numMenos75)

#Graficar la distribucion normal
x = np.linspace(media - 4 * desvEst, media + 4 * desvEst, 1000)
y = norm.pdf(x, media, desvEst)
plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x <= pesoLim), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese menos de 75kg. \n $\mu=70$, $\sigma=4$, X = 500')
plt.xlabel("Peso en kg de los estudiantes")
plt.ylabel("Densidad de Probabilidad")
plt.grid(True)
plt.show()
# Out:
# Probabilidad de que un estudiante pese menos de 75kg 0.9877755273449553
# Numero de estudiantes que pesan menos de 75kg: 493.88776367247766

# %% [markdown]
# ##Cuantos estudiantes pesan menos de 62kg.

# %%
plt.figure (figsize=(6, 4))
media = 70
desvEst = 4
totalEstudiantes = 500
pesoLim = 62 #Variable para calcular la probabilidad de que un estudiante pese menos de 62kg

probMenos62 = norm.cdf(pesoLim, media, desvEst)
#Ahora calculamos el numero de estudiantes que pesan menos de 62kg
numMenos62 = probMenos62 * totalEstudiantes
print("Probabilidad de que un estudiante pese menos de 62kg", probMenos62)
print("Numero de estudiantes que pesan menos de 62kg:", numMenos62)

#Graficar la distribucion normal
x = np.linspace(media - 4 * desvEst, media + 4 * desvEst, 1000)
y = norm.pdf(x, media, desvEst)
plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x <= pesoLim), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese menos de 62kg. \n $\mu=70$, $\sigma=4$, X = 500')
plt.xlabel("Peso en kg de los estudiantes")
plt.ylabel("Densidad de Probabilidad")
plt.grid(True)
plt.show()
# Out:
# Probabilidad de que un estudiante pese menos de 62kg 0.022750131948179195
# Numero de estudiantes que pesan menos de 62kg: 11.375065974089598

# %% [markdown]
# ##Cuantos estudiantes pesan mas de 79kg

# %%
plt.figure (figsize=(6, 4))
media = 70
desvEst = 4
totalEstudiantes = 500
pesoLim = 79 #Variable para calcular la probabilidad de que un estudiante pese menos o igual de 79kg

probMenos79 = norm.cdf(pesoLim, media, desvEst)
probMas79 = 1 - probMenos79
#Ahora calculamos el numero de estudiantes que pesan menos de 75kg
numMas79 = probMas79 * totalEstudiantes
print("Probabilidad de que un estudiante pese mas de 79kg", probMas79)
print("Numero aproximado de estudiantes que pesan mas de 79kg:", numMas79)

#Graficar la distribucion normal
x = np.linspace(media - 4 * desvEst, media + 4 * desvEst, totalEstudiantes)
y = norm.pdf(x, media, desvEst)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x >= pesoLim), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese menos de 75kg. \n $\mu=70$, $\sigma=4$, X = 500')
plt.xlabel("Peso en kg de los estudiantes")
plt.ylabel("Densidad de Probabilidad")
plt.grid(True)
plt.show()
# Out:
# Probabilidad de que un estudiante pese mas de 79kg 0.012224472655044671
# Numero aproximado de estudiantes que pesan mas de 79kg: 6.112236327522336

# %% [markdown]
# ##Cuantos estudiantes pesan mas de 68 y menos de 72

# %%
# Parámetros
media = 70           # Media (μ)
desvEst = 4          # Desviación estándar (σ)
totalEstudiantes = 500
pesoInferior = 68
pesoSuperior = 72

# Calcular la probabilidad entre 68 y 72 kg
probEntre68y72 = norm.cdf(pesoSuperior, media, desvEst) - norm.cdf(pesoInferior, media, desvEst)
numEntre68y72 = probEntre68y72 * totalEstudiantes

# Mostrar resultados
print("Probabilidad de que un estudiante pese entre 68 kg y 72 kg:", round(probEntre68y72, 4))
print("Número aproximado de estudiantes que pesan entre 68 kg y 72 kg:", int(numEntre68y72))

# Crear gráfica
x = np.linspace(media - 4 * desvEst, media + 4 * desvEst, 1000)
y = norm.pdf(x, media, desvEst)

plt.figure(figsize=(8, 5))
plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x >= pesoInferior) & (x <= pesoSuperior), color='skyblue', alpha=0.6)

plt.title('Distribución Normal del Peso\nÁrea entre 68 kg y 72 kg')
plt.xlabel("Peso en kg de los estudiantes")
plt.ylabel("Densidad de Probabilidad")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Probabilidad de que un estudiante pese entre 68 kg y 72 kg: 0.3829
# Número aproximado de estudiantes que pesan entre 68 kg y 72 kg: 191

# %% [markdown]
# #Practica 3. Problema de Distribución binomial y de Poisson

# %% [markdown]
# Antes de resolver el problema especifique si la solución es de tipo Binomial o Poisson y explique por qué.
#
# Realizar un programa en Python que resuelva el siguiente problema:
#
# El número x de personas ingresadas a una unidad de cuidados intensivos en un hospital particular, en un día, tiene una distribución de probabilidad de Poisson con media igual a cinco personas por día.
# a).¿Cuál es la probabilidad de que el número de personas ingresadas a una unidad de cuidados intensivos en un hospital particular, en un día particular, sea dos?
# b).¿Es probable que x exceda de 10? Explicar
# ##Tipo de distribución:
# Este problema es de tipo Poisson.
#
# ¿Por qué? Porque describe el número de eventos (personas ingresadas) que ocurren durante un intervalo en un tiempo fijo establecido (un día), y por que los eventos son independientes entre si, ocurren con una tasa de promedio ya conocida (es igual a 5) y se presentan de manera aleatoria.

# %%
from scipy.stats import poisson
#Media (Lambda) de la distribución de Poisson
media = 5

#Probabilidad de que x sea igual a 2 (osea que ingresen exactamente dos personas)
prob2Personas = poisson.pmf(2, media)

print("a) La probabilidad de que ingresen 2 personas:", prob2Personas)

#b) ¿Es probable que x exceda de 10?
#La formula sería P(X > 10) = 1 - P(X <= 10)
probMas10 = 1 - poisson.cdf(10, media)

print("b) La probabilidad de que ingresen más de 10 personas:", probMas10)

#Explicacion con un condicional para b)
if probMas10 < 0.05:
    print("→ No es probable que ingresen más de 10 personas (menos del 5%)")
else:
    print("→ Sí es probable que ingresen más de 10 personas (más del 5%)")
# Out:
# a) La probabilidad de que ingresen 2 personas: 0.08422433748856832
# b) La probabilidad de que ingresen más de 10 personas: 0.013695268598382881
# → No es probable que ingresen más de 10 personas (menos del 5%)

# %% [markdown]
# Al calcular la probabilidad de que mas de 10 personas ingresen al hospital, se obtiene una probabilidad muy baja, por lo que no es posible que mas de 10 personas entren en un solo día.

# %% [markdown]
# ##Problema 2
# Antes de resolver el problema especifique si la solución es de tipo Binomial o Poisson y explique por qué.
#
# Un fabricantes de podadoras para el pasto compra motores de 1 hp y 2 ciclos, en lotes de 1,000, a un proveedor.
# El fabricante equipa cada una de las podadoras producidas por su planta con uno de los motores.
# La historia muestra que la probabilidad de que cualquier motor del proveedor resulte no satisfactorio es .001.
# En un embarque de 1,000 motores, Calcular
# a).¿Cuál es la probabilidad de que ninguno sea defectuoso?
# b).¿Cuál es la probabilidad de que tres sean defectuosos?
# c).¿Cuál es la probabilidad de que cuatro sean defectuosos?

# %% [markdown]
# ##Tipo de distribucion
# Es de tipo Binomial ya que se tiene un número fijo de intentos (1,000)
#
# Cada motor solo tiene dos posibles resultados (defectuoso o no defectuoso)
#
# La probabilidad de que un motor sea defectuoso es constante (p = 0.001)
#
# Los eventos son independientes

# %%
from scipy.stats import binom

#Número de intentos (motores)
n = 1000

#Probabilidad de motor defectuoso
p = 0.001 #1%

#a) Probabilidad de que ningun motor sea defectuoso
prob0 = binom.pmf(0, n, p)

print("a) La probabilidad de que ninguno sea defectuoso:", prob0)

# b) probabilidad de que tres motores sean defectuosos
prob3 = binom.pmf(3, n, p)

print("b) La probabilidad de que tres motores sean defectuosos:", prob3)

# c) probabilidad de que cuatro motores sean defectuosos
prob4 = binom.pmf(4, n, p)

print("c) La probabilidad de que cuatro motores sean defectuosos:", prob4)
# Out:
# a) La probabilidad de que ninguno sea defectuoso: 0.3676954247709639
# b) La probabilidad de que tres motores sean defectuosos: 0.061282509389840666
# c) La probabilidad de que cuatro motores sean defectuosos: 0.015289955420838651
